# %%
import whisper
from pytube import YouTube, Channel
import pandas as pd

# %%
video_url = "https://www.youtube.com/watch?v=enmam5ad6b8"

audio_file = YouTube(video_url).streams.filter(
    only_audio=True).first().download(filename="audio.mp4")

# %%
whisper_model = whisper.load_model("small")
transcription = whisper_model.transcribe(audio_file)#, language="ja", task="trascribe")

df = pd.DataFrame(data=transcription['segments'], columns=['start', 'end', 'text'])

df
# Out:
# c:\Users\brigh\anaconda3\envs\kato-db\lib\site-packages\whisper\transcribe.py:114: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#     start    end                       text
# 0     0.0    3.0       俺の行きつけの名刺書が出作してた俺なんか
# 1     3.0    5.0                この前たまったまんさぁ
# 2     5.0    7.0                 あの出りひり読んだら
# 3     7.0    9.0      うんこちゃんじゃんって言われたらやってきて
# 4     9.0   11.0              あの全然エッチできなかった
# ..    ...    ...                        ...
# 88  179.0  183.0  携帯でそういった写真を見ながら抜いてもらうっていう
# 89  184.0  186.0                      昔はやつだ
# 90  186.0  188.0           ちょまわり俺携帯撮ってから仕事で
# 91  188.0  189.0                   って嘘つきながら
# 92  189.0  190.0                       とーって
#
# [93 rows x 3 columns]

# %%
transcription
# Out:
# {'text': '俺の生きつけのメンスよが遭遇してた俺のかこの前たまったまさーあのデリヒル頑張ったら運動チャンジアって言われたって言ってあの全然エッジ行けなかった エッジ行ったとか生的接触できなかった もうそうだよ全然生きだよーって言ったなぁそれで引っ張っちゃって全然生的接触できなかった いいよ別に俺エッジするために4年絵からさまあ座って水でもご見ないよ 90分喋って終わったじゃあびっくりしてたんじゃない いやぁってうんそうだよー影響だよってどう開けてよーこちゃんの頼んだわ なったしかに知ってでも知らない振りしたわいい もうどっちでもいいんじゃない帰りきゃリウンコちゃんで伺える 何かが言うのかねーその日の気分かないやさすげぇデリヒルは昔はカトン時にって 言わけ取ったんだけどなんかちょっと恥ずかしくなって1かは1かはって言われてもらって1かは適当恥さがわとかわかなとかその辺いやまだあとかシリアイの名前シリーズで攻めてるババーとか大多活祭とかその辺かなwwwみんなが俺の視聴者がうるいと行く時みんなかとおじいじやくしてければあの解決者だからみんなかとおじいじよくしてマイルドにしていこうこの世の家庭で一応どうしたらバレない不足って疑名で呼べるのを怖くね微分症犠牲なのもうないんじゃないでも初めてのお客様はあれだなんか定員さんがついてきてこういうことしないでかさこういうことしないでかしないでかさいつて注意されてからじゃない証明もされたことない店によるんだんーやべ高いところもいくけどやすいところも全然いって証明なんかしたことないわね元気もとしてばいばいやで多分ねお名数って証明あるんだ俺あんまりいかないからわからないカトさんシティーヘブを見たでどのタイミングでいますか俺恥ずかしくて言えない普通に今全然ノラの客だよって電話電話電話でいばいいんだうーん電話つ付属って選んでるときあたるしんだよな本当にあり何で一番幸せじゃない飲食店で飯選んでるときとあの情報師で情報サイトで不足選んでるときあれもう最高だよな俺も久々な味わいてよなんか首を言ってる女とエッジできなくてラブを手る日に解散したときとかに呼ぶ不足の良さなんなら俺は俺心の中ではいやお前なんて結局腐催だからなと思いながらお腹の出るからでどうか言われよはいことあった俺不足が呼びてんだからことあって見るよって言ってはいことあったさよならすぐにしてくるんで不足をしてから本息で首を居けなくなった結局お前は全然なんだそういうとりめちゃくん死ぬほど不足って死ぬほど不足って死ぬほどないなから抜いてもらう携帯でそういうと写真を見ながら抜いてもらうっていう昔はやつはちょまり俺ケーター撮影が仕事でって嘘つきながらどうって',
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 5.0,
#    'text': '俺の生きつけのメンスよが遭遇してた俺のかこの前たまったまさー',
#    'tokens': [50364,
#     37334,
#     2972,
#     8244,
#     7016,
#     9335,
#     7625,
#     2972,
#     21647,
#     4824,
#     9550,
#     5591,
#     5142,
#     3330,
#     255,
#     3330,
#     229,
#     8822,
#     3368,
#     37334,
#     2972,
#     3703,
#     13303,
#     8945,
#     3368,
#     2889,
#     10102,
#     2889,
#     6722,
#     3384,
#     50614],
#    'temperature': 0.0,
#    'avg_logprob': -0.63886605239496,
#    'compression_ratio': 1.8013698630136987,
#    'no_speech_prob': 0.4456559121608734},
#   {'id': 1,
#    'seek': 0,
#    'start': 5.0,
#    'end': 9.0,
#    'text': 'あのデリヒル頑張ったら運動チャンジアって言われたって言って',
#    'tokens': [50614,
#     24910,
#     31327,
#     12376,
#     46995,
#     9405,
#     8313,
#     239,
#     18889,
#     10102,
#     5154,
#     32772,
#     12572,
#     31771,
#     4824,
#     14655,
#     12817,
#     6102,
#     12009,
#     9206,
#     35478,
#     6102,
#     12009,
#     6102,
#     50814],
#    'temperature': 0.0,
#    'avg_logprob': -0.63886605239496,
#    'compression_ratio': 1.8013698630136987,
#    'no_speech_prob': 0.4456559121608734},
#   {'id': 2,
#    'seek': 0,
#    'start': 9.0,
#    'end': 11.0,
#    'text': 'あの全然エッジ行けなかった エッジ行ったとか',
#    'tokens': [50814,
#     24910,
#     11319,
#     5823,
#     26215,
#     8276,
#     14655,
#     8082,
#     7625,
#     3203,
#     25785,
#     220,
#     26215,
#     8276,
#     14655,
#     8082,
#     10102,
#     30607,
#     50914],
#    'temperature': 0.0,
#    'avg_logprob': -0.63886605239496,
#    'compression_ratio': 1.8013698630136987,
#    'no_speech_prob': 0.4456559121608734},
#   {'id': 3,
#    'seek': 0,
#    'start': 11.0,
#    'end': 14.0,
#    'text': '生的接触できなかった もうそうだよ',
#    'tokens': [50914,
#     8244,
#     1546,
#     14468,
#     6758,
#     99,
#     43200,
#     3203,
#     25785,
#     220,
#     16324,
#     39471,
#     5591,
#     51064],
#    'temperature': 0.0,
#    'avg_logprob': -0.63886605239496,
#    'compression_ratio': 1.8013698630136987,
#    'no_speech_prob': 0.4456559121608734},
#   {'id': 4,
#    'seek': 0,
#    'start': 14.0,
#    'end': 16.0,
#    'text': '全然生きだよーって言ったなぁ',
#    'tokens': [51064,
#     11319,
#     5823,
#     8244,
#     7016,
#     5362,
#     5591,
#     3384,
#     6102,
#     12009,
#     10102,
#     3203,
#     11951,
#     51164],
#    'temperature': 0.0,
#    'avg_logprob': -0.63886605239496,
#    'compression_ratio': 1.8013698630136987,
#    'no_speech_prob': 0.4456559121608734},
#   {'id': 5,
#    'seek': 0,
#    'start': 16.0,
#    'end': 19.0,
#    'text': 'それで引っ張っちゃって全然',
#    'tokens': [51164,
#     48466,
#     41301,
#     2970,
#     18889,
#     41380,
#     6102,
#     11319,
#     5823,
#     51314],
#    'temperature': 0.0,
#    'avg_logprob': -0.63886605239496,
#    'compression_ratio': 1.8013698630136987,
#    'no_speech_prob': 0.4456559121608734},
#   {'id': 6,
#    'seek': 0,
#    'start': 19.0,
#    'end': 23.0,
#    'text': '生的接触できなかった いいよ別に俺エッジするために4年絵からさ',
#    'tokens': [51314,
#     8244,
#     1546,
#     14468,
#     6758,
#     99,
#     43200,
#     3203,
#     25785,
#     220,
#     13806,
#     5591,
#     16158,
#     4108,
#     37334,
#     26215,
#     8276,
#     14655,
#     22570,
#     49983,
#     4108,
#     19,
#     5157,
#     6948,
#     113,
#     11046,
#     6722,
#     51514],
#    'temperature': 0.0,
#    'avg_logprob': -0.63886605239496,
#    'compression_ratio': 1.8013698630136987,
#    'no_speech_prob': 0.4456559121608734},
#   {'id': 7,
#    'seek': 0,
#    'start': 23.0,
#    'end': 26.0,
#    'text': 'まあ座って水でもご見ないよ 90分喋って終わった',
#    'tokens': [51514,
#     32763,
#     6346,
#     100,
#     6102,
#     15590,
#     17783,
#     9991,
#     10470,
#     9311,
#     5591,
#     220,
#     7771,
#     6627,
#     5234,
#     233,
#     6102,
#     29371,
#     9206,
#     10102,
#     51664],
#    'temperature': 0.0,
#    'avg_logprob': -0.63886605239496,
#    'compression_ratio': 1.8013698630136987,
#    'no_speech_prob': 0.4456559121608734},
#   {'id': 8,
#    'seek': 2600,
#    'start': 26.0,
#    'end': 30.0,
#    'text': 'じゃあびっくりしてたんじゃない いやぁって',
#    'tokens': [50364,
#     31284,
#     38761,
#     2970,
#     6134,
#     5095,
#     8822,
#     3368,
#     3225,
#     40323,
#     220,
#     18524,
#     11951,
#     6102,
#     50564],
#    'temperature': 0.6,
#    'avg_logprob': -0.7498384731919018,
#    'compression_ratio': 1.7088122605363985,
#    'no_speech_prob': 0.31640031933784485},
#   {'id': 9,
#    'seek': 2600,
#    'start': 30.0,
#    'end': 32.0,
#    'text': 'うんそうだよー',
#    'tokens': [50564, 17760, 39471, 5591, 3384, 50664],
#    'temperature': 0.6,
#    'avg_logprob': -0.7498384731919018,
#    'compression_ratio': 1.7088122605363985,
#    'no_speech_prob': 0.31640031933784485},
#   {'id': 10,
#    'seek': 2600,
#    'start': 32.0,
#    'end': 34.0,
#    'text': '影響だよって',
#    'tokens': [50664, 16820, 13665, 123, 5362, 5591, 6102, 50764],
#    'temperature': 0.6,
#    'avg_logprob': -0.7498384731919018,
#    'compression_ratio': 1.7088122605363985,
#    'no_speech_prob': 0.31640031933784485},
#   {'id': 11,
#    'seek': 2600,
#    'start': 34.0,
#    'end': 36.0,
#    'text': 'どう開けてよーこちゃんの頼んだわ なったしかに',
#    'tokens': [50764,
#     18395,
#     8949,
#     39736,
#     5591,
#     3384,
#     3503,
#     35771,
#     2972,
#     8313,
#     120,
#     26983,
#     9206,
#     16647,
#     10102,
#     32156,
#     4108,
#     50864],
#    'temperature': 0.6,
#    'avg_logprob': -0.7498384731919018,
#    'compression_ratio': 1.7088122605363985,
#    'no_speech_prob': 0.31640031933784485},
#   {'id': 12,
#    'seek': 2600,
#    'start': 39.0,
#    'end': 45.0,
#    'text': '知ってでも知らない振りしたわいい もうどっちでもいいんじゃない',
#    'tokens': [51014,
#     6498,
#     6102,
#     17783,
#     6498,
#     5154,
#     9311,
#     8501,
#     107,
#     5095,
#     8533,
#     9206,
#     13806,
#     220,
#     16324,
#     7594,
#     39046,
#     17783,
#     13806,
#     3225,
#     40323,
#     51314],
#    'temperature': 0.6,
#    'avg_logprob': -0.7498384731919018,
#    'compression_ratio': 1.7088122605363985,
#    'no_speech_prob': 0.31640031933784485},
#   {'id': 13,
#    'seek': 2600,
#    'start': 45.0,
#    'end': 49.0,
#    'text': '帰りきゃリウンコちゃんで伺える 何かが言うのかねー',
#    'tokens': [51314,
#     4845,
#     108,
#     5095,
#     7016,
#     9051,
#     12376,
#     20745,
#     4824,
#     18066,
#     35771,
#     2474,
#     7384,
#     118,
#     44547,
#     220,
#     11906,
#     3703,
#     5142,
#     12009,
#     2646,
#     2972,
#     3703,
#     5555,
#     3384,
#     51514],
#    'temperature': 0.6,
#    'avg_logprob': -0.7498384731919018,
#    'compression_ratio': 1.7088122605363985,
#    'no_speech_prob': 0.31640031933784485},
#   {'id': 14,
#    'seek': 2600,
#    'start': 49.0,
#    'end': 51.0,
#    'text': 'その日の気分かな',
#    'tokens': [51514, 20564, 6890, 2972, 25870, 6627, 24939, 51614],
#    'temperature': 0.6,
#    'avg_logprob': -0.7498384731919018,
#    'compression_ratio': 1.7088122605363985,
#    'no_speech_prob': 0.31640031933784485},
#   {'id': 15,
#    'seek': 2600,
#    'start': 51.0,
#    'end': 55.0,
#    'text': 'いやさすげぇデリヒルは昔はカトン時にって 言わけ取ったんだけど',
#    'tokens': [51614,
#     18524,
#     6722,
#     2659,
#     26012,
#     20861,
#     31327,
#     12376,
#     46995,
#     9405,
#     3065,
#     1431,
#     242,
#     3065,
#     10111,
#     7588,
#     4824,
#     6611,
#     4108,
#     6102,
#     220,
#     12009,
#     9206,
#     7625,
#     29436,
#     10102,
#     26983,
#     21891,
#     51814],
#    'temperature': 0.6,
#    'avg_logprob': -0.7498384731919018,
#    'compression_ratio': 1.7088122605363985,
#    'no_speech_prob': 0.31640031933784485},
#   {'id': 16,
#    'seek': 5500,
#    'start': 55.0,
#    'end': 57.0,
#    'text': 'なんかちょっと恥ずかしくなって',
#    'tokens': [50364,
#     27646,
#     21888,
#     11845,
#     98,
#     18216,
#     3703,
#     26568,
#     3203,
#     6102,
#     50464],
#    'temperature': 0.0,
#    'avg_logprob': -0.6421425901813271,
#    'compression_ratio': 1.7387755102040816,
#    'no_speech_prob': 0.20943792164325714},
#   {'id': 17,
#    'seek': 5500,
#    'start': 57.0,
#    'end': 59.34,
#    'text': '1かは1かはって言われてもらって',
#    'tokens': [50464,
#     16,
#     3703,
#     3065,
#     16,
#     3703,
#     3065,
#     6102,
#     12009,
#     9206,
#     26638,
#     4801,
#     5154,
#     6102,
#     50581],
#    'temperature': 0.0,
#    'avg_logprob': -0.6421425901813271,
#    'compression_ratio': 1.7387755102040816,
#    'no_speech_prob': 0.20943792164325714},
#   {'id': 18,
#    'seek': 5500,
#    'start': 59.34,
#    'end': 60.34,
#    'text': '1かは',
#    'tokens': [50581, 16, 3703, 3065, 50631],
#    'temperature': 0.0,
#    'avg_logprob': -0.6421425901813271,
#    'compression_ratio': 1.7387755102040816,
#    'no_speech_prob': 0.20943792164325714},
#   {'id': 19,
#    'seek': 5500,
#    'start': 60.34,
#    'end': 61.34,
#    'text': '適当',
#    'tokens': [50631, 3330, 102, 16233, 50681],
#    'temperature': 0.0,
#    'avg_logprob': -0.6421425901813271,
#    'compression_ratio': 1.7387755102040816,
#    'no_speech_prob': 0.20943792164325714},
#   {'id': 20,
#    'seek': 5500,
#    'start': 61.34,
#    'end': 62.34,
#    'text': '恥さがわとか',
#    'tokens': [50681, 11845, 98, 6722, 5142, 9206, 30607, 50731],
#    'temperature': 0.0,
#    'avg_logprob': -0.6421425901813271,
#    'compression_ratio': 1.7387755102040816,
#    'no_speech_prob': 0.20943792164325714},
#   {'id': 21,
#    'seek': 5500,
#    'start': 62.34,
#    'end': 63.34,
#    'text': 'わかなとか',
#    'tokens': [50731, 9206, 24939, 30607, 50781],
#    'temperature': 0.0,
#    'avg_logprob': -0.6421425901813271,
#    'compression_ratio': 1.7387755102040816,
#    'no_speech_prob': 0.20943792164325714},
#   {'id': 22,
#    'seek': 5500,
#    'start': 63.34,
#    'end': 64.34,
#    'text': 'その辺',
#    'tokens': [50781, 20564, 9830, 118, 50831],
#    'temperature': 0.0,
#    'avg_logprob': -0.6421425901813271,
#    'compression_ratio': 1.7387755102040816,
#    'no_speech_prob': 0.20943792164325714},
#   {'id': 23,
#    'seek': 5500,
#    'start': 64.34,
#    'end': 65.84,
#    'text': 'いやまだあとか',
#    'tokens': [50831, 18524, 47185, 37015, 3703, 50906],
#    'temperature': 0.0,
#    'avg_logprob': -0.6421425901813271,
#    'compression_ratio': 1.7387755102040816,
#    'no_speech_prob': 0.20943792164325714},
#   {'id': 24,
#    'seek': 5500,
#    'start': 65.84,
#    'end': 67.84,
#    'text': 'シリアイの',
#    'tokens': [50906, 11054, 12376, 12817, 8040, 2972, 51006],
#    'temperature': 0.0,
#    'avg_logprob': -0.6421425901813271,
#    'compression_ratio': 1.7387755102040816,
#    'no_speech_prob': 0.20943792164325714},
#   {'id': 25,
#    'seek': 5500,
#    'start': 67.84,
#    'end': 69.84,
#    'text': '名前シリーズで',
#    'tokens': [51006, 15940, 8945, 11054, 12376, 3384, 29061, 2474, 51106],
#    'temperature': 0.0,
#    'avg_logprob': -0.6421425901813271,
#    'compression_ratio': 1.7387755102040816,
#    'no_speech_prob': 0.20943792164325714},
#   {'id': 26,
#    'seek': 5500,
#    'start': 69.84,
#    'end': 70.84,
#    'text': '攻めてる',
#    'tokens': [51106, 41530, 38975, 4895, 51156],
#    'temperature': 0.0,
#    'avg_logprob': -0.6421425901813271,
#    'compression_ratio': 1.7387755102040816,
#    'no_speech_prob': 0.20943792164325714},
#   {'id': 27,
#    'seek': 5500,
#    'start': 70.84,
#    'end': 72.34,
#    'text': 'ババーとか',
#    'tokens': [51156, 18593, 18593, 3384, 30607, 51231],
#    'temperature': 0.0,
#    'avg_logprob': -0.6421425901813271,
#    'compression_ratio': 1.7387755102040816,
#    'no_speech_prob': 0.20943792164325714},
#   {'id': 28,
#    'seek': 5500,
#    'start': 72.34,
#    'end': 73.84,
#    'text': '大多活祭とか',
#    'tokens': [51231, 3582, 6392, 25956, 12695, 255, 30607, 51306],
#    'temperature': 0.0,
#    'avg_logprob': -0.6421425901813271,
#    'compression_ratio': 1.7387755102040816,
#    'no_speech_prob': 0.20943792164325714},
#   {'id': 29,
#    'seek': 5500,
#    'start': 73.84,
#    'end': 74.84,
#    'text': 'その辺かな',
#    'tokens': [51306, 20564, 9830, 118, 24939, 51356],
#    'temperature': 0.0,
#    'avg_logprob': -0.6421425901813271,
#    'compression_ratio': 1.7387755102040816,
#    'no_speech_prob': 0.20943792164325714},
#   {'id': 30,
#    'seek': 5500,
#    'start': 74.84,
#    'end': 76.84,
#    'text': 'www',
#    'tokens': [51356, 17919, 51456],
#    'temperature': 0.0,
#    'avg_logprob': -0.6421425901813271,
#    'compression_ratio': 1.7387755102040816,
#    'no_speech_prob': 0.20943792164325714},
#   {'id': 31,
#    'seek': 5500,
#    'start': 76.84,
#    'end': 78.58,
#    'text': 'みんなが俺の視聴者が',
#    'tokens': [51456,
#     11362,
#     16548,
#     5142,
#     37334,
#     2972,
#     27333,
#     8171,
#     112,
#     12444,
#     5142,
#     51543],
#    'temperature': 0.0,
#    'avg_logprob': -0.6421425901813271,
#    'compression_ratio': 1.7387755102040816,
#    'no_speech_prob': 0.20943792164325714},
#   {'id': 32,
#    'seek': 5500,
#    'start': 78.58,
#    'end': 79.08,
#    'text': 'うるいと行く時',
#    'tokens': [51543, 2646, 4895, 1764, 3193, 8082, 6134, 6611, 51568],
#    'temperature': 0.0,
#    'avg_logprob': -0.6421425901813271,
#    'compression_ratio': 1.7387755102040816,
#    'no_speech_prob': 0.20943792164325714},
#   {'id': 33,
#    'seek': 5500,
#    'start': 79.08,
#    'end': 81.08,
#    'text': 'みんなかとおじいじやくしてければ',
#    'tokens': [51568,
#     11362,
#     16548,
#     3703,
#     3193,
#     6117,
#     9257,
#     1764,
#     9257,
#     7355,
#     6134,
#     8822,
#     39256,
#     13349,
#     51668],
#    'temperature': 0.0,
#    'avg_logprob': -0.6421425901813271,
#    'compression_ratio': 1.7387755102040816,
#    'no_speech_prob': 0.20943792164325714},
#   {'id': 34,
#    'seek': 5500,
#    'start': 81.08,
#    'end': 82.28,
#    'text': 'あの解決者だから',
#    'tokens': [51668, 24910, 17278, 33540, 12444, 33183, 51728],
#    'temperature': 0.0,
#    'avg_logprob': -0.6421425901813271,
#    'compression_ratio': 1.7387755102040816,
#    'no_speech_prob': 0.20943792164325714},
#   {'id': 35,
#    'seek': 5500,
#    'start': 82.28,
#    'end': 84.28,
#    'text': 'みんなかとおじいじよくして',
#    'tokens': [51728,
#     11362,
#     16548,
#     3703,
#     3193,
#     6117,
#     9257,
#     1764,
#     9257,
#     5591,
#     6134,
#     8822,
#     51828],
#    'temperature': 0.0,
#    'avg_logprob': -0.6421425901813271,
#    'compression_ratio': 1.7387755102040816,
#    'no_speech_prob': 0.20943792164325714},
#   {'id': 36,
#    'seek': 8428,
#    'start': 84.28,
#    'end': 86.12,
#    'text': 'マイルドにしていこう',
#    'tokens': [50364, 13258, 8040, 9405, 11195, 4108, 8822, 1764, 22159, 50456],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 37,
#    'seek': 8428,
#    'start': 86.12,
#    'end': 88.28,
#    'text': 'この世の家庭で一応',
#    'tokens': [50456,
#     13303,
#     17484,
#     2972,
#     5155,
#     6346,
#     255,
#     2474,
#     2257,
#     4263,
#     250,
#     50564],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 38,
#    'seek': 8428,
#    'start': 88.28,
#    'end': 89.76,
#    'text': 'どうしたらバレない',
#    'tokens': [50564, 18395, 8533, 5154, 18593, 16680, 9311, 50638],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 39,
#    'seek': 8428,
#    'start': 89.76,
#    'end': 90.24,
#    'text': '不足って',
#    'tokens': [50638, 1960, 37236, 6102, 50662],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 40,
#    'seek': 8428,
#    'start': 90.24,
#    'end': 91.04,
#    'text': '疑名で呼べるのを',
#    'tokens': [50662,
#     18140,
#     239,
#     15940,
#     2474,
#     38718,
#     28043,
#     4895,
#     2972,
#     5998,
#     50702],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 41,
#    'seek': 8428,
#    'start': 91.04,
#    'end': 91.48,
#    'text': '怖くね',
#    'tokens': [50702, 39647, 6134, 5555, 50724],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 42,
#    'seek': 8428,
#    'start': 91.48,
#    'end': 92.88,
#    'text': '微分症犠牲なの',
#    'tokens': [50724,
#     39152,
#     6627,
#     15553,
#     229,
#     35276,
#     254,
#     6935,
#     110,
#     3203,
#     2972,
#     50794],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 43,
#    'seek': 8428,
#    'start': 92.88,
#    'end': 94.08,
#    'text': 'もうないんじゃない',
#    'tokens': [50794, 16324, 9311, 3225, 40323, 50854],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 44,
#    'seek': 8428,
#    'start': 94.08,
#    'end': 96.04,
#    'text': 'でも初めてのお客様は',
#    'tokens': [50854,
#     17783,
#     28727,
#     38975,
#     2972,
#     6117,
#     32316,
#     49261,
#     3065,
#     50952],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 45,
#    'seek': 8428,
#    'start': 96.04,
#    'end': 96.72,
#    'text': 'あれだ',
#    'tokens': [50952, 30659, 5362, 50986],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 46,
#    'seek': 8428,
#    'start': 96.72,
#    'end': 97.72,
#    'text': 'なんか',
#    'tokens': [50986, 27646, 51036],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 47,
#    'seek': 8428,
#    'start': 97.72,
#    'end': 99.24000000000001,
#    'text': '定員さんがついてきて',
#    'tokens': [51036,
#     12088,
#     20992,
#     15567,
#     5142,
#     9335,
#     18549,
#     7016,
#     2996,
#     51112],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 48,
#    'seek': 8428,
#    'start': 99.24000000000001,
#    'end': 99.96000000000001,
#    'text': 'こういうことしないでか',
#    'tokens': [51112, 22159, 39773, 2849, 9311, 2474, 3703, 51148],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 49,
#    'seek': 8428,
#    'start': 99.96000000000001,
#    'end': 100.96000000000001,
#    'text': 'さこういうことしないでか',
#    'tokens': [51148, 6722, 22159, 39773, 2849, 9311, 2474, 3703, 51198],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 50,
#    'seek': 8428,
#    'start': 100.96000000000001,
#    'end': 101.76,
#    'text': 'しないでか',
#    'tokens': [51198, 2849, 9311, 2474, 3703, 51238],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 51,
#    'seek': 8428,
#    'start': 101.76,
#    'end': 102.76,
#    'text': 'さいつて',
#    'tokens': [51238, 6722, 40162, 2996, 51288],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 52,
#    'seek': 8428,
#    'start': 102.76,
#    'end': 103.84,
#    'text': '注意されてから',
#    'tokens': [51288, 40794, 6722, 26638, 11046, 51342],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 53,
#    'seek': 8428,
#    'start': 103.84,
#    'end': 105.08,
#    'text': 'じゃない',
#    'tokens': [51342, 40323, 51404],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 54,
#    'seek': 8428,
#    'start': 105.08,
#    'end': 107.24000000000001,
#    'text': '証明もされたことない',
#    'tokens': [51404, 5396, 120, 11100, 4801, 6722, 35478, 13235, 9311, 51512],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 55,
#    'seek': 8428,
#    'start': 107.24000000000001,
#    'end': 108.48,
#    'text': '店によるんだ',
#    'tokens': [51512, 22469, 4108, 5591, 4895, 26983, 51574],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 56,
#    'seek': 8428,
#    'start': 108.48,
#    'end': 109.48,
#    'text': 'んー',
#    'tokens': [51574, 3225, 3384, 51624],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 57,
#    'seek': 8428,
#    'start': 109.48,
#    'end': 109.8,
#    'text': 'やべ',
#    'tokens': [51624, 7355, 28043, 51640],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 58,
#    'seek': 8428,
#    'start': 109.8,
#    'end': 110.44,
#    'text': '高いところも',
#    'tokens': [51640, 12979, 1764, 46001, 4801, 51672],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 59,
#    'seek': 8428,
#    'start': 110.44,
#    'end': 110.74000000000001,
#    'text': 'いくけど',
#    'tokens': [51672, 49394, 21891, 51687],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 60,
#    'seek': 8428,
#    'start': 110.74000000000001,
#    'end': 111.44,
#    'text': 'やすいところも',
#    'tokens': [51687, 7355, 2659, 1764, 46001, 4801, 51722],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 61,
#    'seek': 8428,
#    'start': 111.44,
#    'end': 112.16,
#    'text': '全然いって',
#    'tokens': [51722, 11319, 5823, 1764, 6102, 51758],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 62,
#    'seek': 8428,
#    'start': 112.16,
#    'end': 114.2,
#    'text': '証明なんかしたことないわ',
#    'tokens': [51758, 5396, 120, 11100, 27646, 8533, 13235, 9311, 9206, 51860],
#    'temperature': 0.0,
#    'avg_logprob': -0.5353786488271131,
#    'compression_ratio': 1.8508474576271186,
#    'no_speech_prob': 0.15298905968666077},
#   {'id': 63,
#    'seek': 11420,
#    'start': 114.2,
#    'end': 115.76,
#    'text': 'ね元気もとしてばいばいやで',
#    'tokens': [50364,
#     5555,
#     14812,
#     25870,
#     4801,
#     3193,
#     8822,
#     42176,
#     13349,
#     18524,
#     2474,
#     50442],
#    'temperature': 0.0,
#    'avg_logprob': -0.4814202260162871,
#    'compression_ratio': 1.6326530612244898,
#    'no_speech_prob': 0.005372604355216026},
#   {'id': 64,
#    'seek': 11420,
#    'start': 115.76,
#    'end': 117.44,
#    'text': '多分ね',
#    'tokens': [50442, 6392, 6627, 5555, 50526],
#    'temperature': 0.0,
#    'avg_logprob': -0.4814202260162871,
#    'compression_ratio': 1.6326530612244898,
#    'no_speech_prob': 0.005372604355216026},
#   {'id': 65,
#    'seek': 11420,
#    'start': 117.44,
#    'end': 118.84,
#    'text': 'お名数って証明あるんだ',
#    'tokens': [50526,
#     6117,
#     15940,
#     33188,
#     6102,
#     5396,
#     120,
#     11100,
#     24719,
#     26983,
#     50596],
#    'temperature': 0.0,
#    'avg_logprob': -0.4814202260162871,
#    'compression_ratio': 1.6326530612244898,
#    'no_speech_prob': 0.005372604355216026},
#   {'id': 66,
#    'seek': 11420,
#    'start': 118.84,
#    'end': 121.60000000000001,
#    'text': '俺あんまりいかないからわからない',
#    'tokens': [50596,
#     37334,
#     3590,
#     3225,
#     41446,
#     1764,
#     3703,
#     9311,
#     11046,
#     9206,
#     11046,
#     9311,
#     50734],
#    'temperature': 0.0,
#    'avg_logprob': -0.4814202260162871,
#    'compression_ratio': 1.6326530612244898,
#    'no_speech_prob': 0.005372604355216026},
#   {'id': 67,
#    'seek': 11420,
#    'start': 121.60000000000001,
#    'end': 122.0,
#    'text': 'カトさん',
#    'tokens': [50734, 10111, 7588, 15567, 50754],
#    'temperature': 0.0,
#    'avg_logprob': -0.4814202260162871,
#    'compression_ratio': 1.6326530612244898,
#    'no_speech_prob': 0.005372604355216026},
#   {'id': 68,
#    'seek': 11420,
#    'start': 122.0,
#    'end': 123.0,
#    'text': 'シティーヘブを見たで',
#    'tokens': [50754,
#     11054,
#     22985,
#     26760,
#     15266,
#     246,
#     28889,
#     5998,
#     10470,
#     3368,
#     2474,
#     50804],
#    'temperature': 0.0,
#    'avg_logprob': -0.4814202260162871,
#    'compression_ratio': 1.6326530612244898,
#    'no_speech_prob': 0.005372604355216026},
#   {'id': 69,
#    'seek': 11420,
#    'start': 123.0,
#    'end': 123.84,
#    'text': 'どのタイミングでいますか',
#    'tokens': [50804,
#     7594,
#     2972,
#     12144,
#     8040,
#     23196,
#     43017,
#     2474,
#     11267,
#     3703,
#     50846],
#    'temperature': 0.0,
#    'avg_logprob': -0.4814202260162871,
#    'compression_ratio': 1.6326530612244898,
#    'no_speech_prob': 0.005372604355216026},
#   {'id': 70,
#    'seek': 11420,
#    'start': 123.84,
#    'end': 124.72,
#    'text': '俺',
#    'tokens': [50846, 37334, 50890],
#    'temperature': 0.0,
#    'avg_logprob': -0.4814202260162871,
#    'compression_ratio': 1.6326530612244898,
#    'no_speech_prob': 0.005372604355216026},
#   {'id': 71,
#    'seek': 11420,
#    'start': 124.72,
#    'end': 126.8,
#    'text': '恥ずかしくて言えない',
#    'tokens': [50890,
#     11845,
#     98,
#     18216,
#     3703,
#     26568,
#     2996,
#     12009,
#     6474,
#     9311,
#     50994],
#    'temperature': 0.0,
#    'avg_logprob': -0.4814202260162871,
#    'compression_ratio': 1.6326530612244898,
#    'no_speech_prob': 0.005372604355216026},
#   {'id': 72,
#    'seek': 11420,
#    'start': 126.8,
#    'end': 127.32000000000001,
#    'text': '普通に',
#    'tokens': [50994, 29993, 19550, 4108, 51020],
#    'temperature': 0.0,
#    'avg_logprob': -0.4814202260162871,
#    'compression_ratio': 1.6326530612244898,
#    'no_speech_prob': 0.005372604355216026},
#   {'id': 73,
#    'seek': 11420,
#    'start': 127.32000000000001,
#    'end': 128.48000000000002,
#    'text': '今全然',
#    'tokens': [51020, 6480, 11319, 5823, 51078],
#    'temperature': 0.0,
#    'avg_logprob': -0.4814202260162871,
#    'compression_ratio': 1.6326530612244898,
#    'no_speech_prob': 0.005372604355216026},
#   {'id': 74,
#    'seek': 11420,
#    'start': 128.48000000000002,
#    'end': 130.52,
#    'text': 'ノラの客だよって',
#    'tokens': [51078, 34501, 11353, 2972, 32316, 5362, 5591, 6102, 51180],
#    'temperature': 0.0,
#    'avg_logprob': -0.4814202260162871,
#    'compression_ratio': 1.6326530612244898,
#    'no_speech_prob': 0.005372604355216026},
#   {'id': 75,
#    'seek': 11420,
#    'start': 130.52,
#    'end': 132.48000000000002,
#    'text': '電話電話電話でいばいいんだ',
#    'tokens': [51180,
#     20545,
#     11103,
#     20545,
#     11103,
#     20545,
#     11103,
#     2474,
#     1764,
#     13349,
#     13806,
#     26983,
#     51278],
#    'temperature': 0.0,
#    'avg_logprob': -0.4814202260162871,
#    'compression_ratio': 1.6326530612244898,
#    'no_speech_prob': 0.005372604355216026},
#   {'id': 76,
#    'seek': 11420,
#    'start': 132.48000000000002,
#    'end': 134.48000000000002,
#    'text': 'うーん',
#    'tokens': [51278, 2646, 46601, 51378],
#    'temperature': 0.0,
#    'avg_logprob': -0.4814202260162871,
#    'compression_ratio': 1.6326530612244898,
#    'no_speech_prob': 0.005372604355216026},
#   {'id': 77,
#    'seek': 11420,
#    'start': 134.48000000000002,
#    'end': 135.48000000000002,
#    'text': '電話つ付属って',
#    'tokens': [51378, 20545, 11103, 9335, 41469, 9636, 252, 6102, 51428],
#    'temperature': 0.0,
#    'avg_logprob': -0.4814202260162871,
#    'compression_ratio': 1.6326530612244898,
#    'no_speech_prob': 0.005372604355216026},
#   {'id': 78,
#    'seek': 11420,
#    'start': 135.48000000000002,
#    'end': 137.04,
#    'text': '選んでるときあたるしんだよな',
#    'tokens': [51428,
#     21625,
#     35356,
#     4895,
#     3193,
#     7016,
#     3590,
#     3368,
#     4895,
#     2849,
#     26983,
#     5591,
#     3203,
#     51506],
#    'temperature': 0.0,
#    'avg_logprob': -0.4814202260162871,
#    'compression_ratio': 1.6326530612244898,
#    'no_speech_prob': 0.005372604355216026},
#   {'id': 79,
#    'seek': 11420,
#    'start': 137.04,
#    'end': 137.92000000000002,
#    'text': '本当にあり',
#    'tokens': [51506, 37505, 4108, 14498, 51550],
#    'temperature': 0.0,
#    'avg_logprob': -0.4814202260162871,
#    'compression_ratio': 1.6326530612244898,
#    'no_speech_prob': 0.005372604355216026},
#   {'id': 80,
#    'seek': 11420,
#    'start': 137.92000000000002,
#    'end': 139.96,
#    'text': '何で一番幸せじゃない',
#    'tokens': [51550, 11906, 2474, 2257, 33118, 36482, 13702, 40323, 51652],
#    'temperature': 0.0,
#    'avg_logprob': -0.4814202260162871,
#    'compression_ratio': 1.6326530612244898,
#    'no_speech_prob': 0.005372604355216026},
#   {'id': 81,
#    'seek': 11420,
#    'start': 139.96,
#    'end': 140.64000000000001,
#    'text': '飲食店で',
#    'tokens': [51652, 11808, 110, 25155, 22469, 2474, 51686],
#    'temperature': 0.0,
#    'avg_logprob': -0.4814202260162871,
#    'compression_ratio': 1.6326530612244898,
#    'no_speech_prob': 0.005372604355216026},
#   {'id': 82,
#    'seek': 11420,
#    'start': 140.64000000000001,
#    'end': 142.16,
#    'text': '飯選んでるときと',
#    'tokens': [51686, 45229, 21625, 35356, 4895, 3193, 7016, 3193, 51762],
#    'temperature': 0.0,
#    'avg_logprob': -0.4814202260162871,
#    'compression_ratio': 1.6326530612244898,
#    'no_speech_prob': 0.005372604355216026},
#   {'id': 83,
#    'seek': 11420,
#    'start': 142.16,
#    'end': 143.12,
#    'text': 'あの',
#    'tokens': [51762, 24910, 51810],
#    'temperature': 0.0,
#    'avg_logprob': -0.4814202260162871,
#    'compression_ratio': 1.6326530612244898,
#    'no_speech_prob': 0.005372604355216026},
#   {'id': 84,
#    'seek': 14312,
#    'start': 143.12,
#    'end': 145.48000000000002,
#    'text': '情報師で情報サイトで',
#    'tokens': [50364,
#     10570,
#     17803,
#     16276,
#     2474,
#     10570,
#     17803,
#     23607,
#     8040,
#     7588,
#     2474,
#     50482],
#    'temperature': 0.0,
#    'avg_logprob': -0.4857870526788359,
#    'compression_ratio': 1.7896253602305476,
#    'no_speech_prob': 0.06274664402008057},
#   {'id': 85,
#    'seek': 14312,
#    'start': 145.48000000000002,
#    'end': 147.08,
#    'text': '不足選んでるとき',
#    'tokens': [50482, 1960, 37236, 21625, 35356, 4895, 3193, 7016, 50562],
#    'temperature': 0.0,
#    'avg_logprob': -0.4857870526788359,
#    'compression_ratio': 1.7896253602305476,
#    'no_speech_prob': 0.06274664402008057},
#   {'id': 86,
#    'seek': 14312,
#    'start': 147.08,
#    'end': 149.48000000000002,
#    'text': 'あれもう最高だよな',
#    'tokens': [50562, 30659, 16324, 8661, 12979, 5362, 5591, 3203, 50682],
#    'temperature': 0.0,
#    'avg_logprob': -0.4857870526788359,
#    'compression_ratio': 1.7896253602305476,
#    'no_speech_prob': 0.06274664402008057},
#   {'id': 87,
#    'seek': 14312,
#    'start': 149.48000000000002,
#    'end': 151.48000000000002,
#    'text': '俺も久々な味わいてよ',
#    'tokens': [50682,
#     37334,
#     4801,
#     25320,
#     45032,
#     3203,
#     17268,
#     9206,
#     18549,
#     5591,
#     50782],
#    'temperature': 0.0,
#    'avg_logprob': -0.4857870526788359,
#    'compression_ratio': 1.7896253602305476,
#    'no_speech_prob': 0.06274664402008057},
#   {'id': 88,
#    'seek': 14312,
#    'start': 151.48000000000002,
#    'end': 153.8,
#    'text': 'なんか首を言ってる女とエッジできなくて',
#    'tokens': [50782,
#     27646,
#     25444,
#     5998,
#     12009,
#     45350,
#     17015,
#     3193,
#     26215,
#     8276,
#     14655,
#     43200,
#     40252,
#     2996,
#     50898],
#    'temperature': 0.0,
#    'avg_logprob': -0.4857870526788359,
#    'compression_ratio': 1.7896253602305476,
#    'no_speech_prob': 0.06274664402008057},
#   {'id': 89,
#    'seek': 14312,
#    'start': 153.8,
#    'end': 155.96,
#    'text': 'ラブを手る日に解散したときとかに',
#    'tokens': [50898,
#     11353,
#     28889,
#     5998,
#     11389,
#     4895,
#     6890,
#     4108,
#     17278,
#     7017,
#     96,
#     8533,
#     3193,
#     7016,
#     30607,
#     4108,
#     51006],
#    'temperature': 0.0,
#    'avg_logprob': -0.4857870526788359,
#    'compression_ratio': 1.7896253602305476,
#    'no_speech_prob': 0.06274664402008057},
#   {'id': 90,
#    'seek': 14312,
#    'start': 155.96,
#    'end': 157.6,
#    'text': '呼ぶ不足の良さ',
#    'tokens': [51006, 38718, 23441, 1960, 37236, 2972, 33950, 6722, 51088],
#    'temperature': 0.0,
#    'avg_logprob': -0.4857870526788359,
#    'compression_ratio': 1.7896253602305476,
#    'no_speech_prob': 0.06274664402008057},
#   {'id': 91,
#    'seek': 14312,
#    'start': 157.6,
#    'end': 158.52,
#    'text': 'なんなら俺は',
#    'tokens': [51088, 11847, 42540, 37334, 3065, 51134],
#    'temperature': 0.0,
#    'avg_logprob': -0.4857870526788359,
#    'compression_ratio': 1.7896253602305476,
#    'no_speech_prob': 0.06274664402008057},
#   {'id': 92,
#    'seek': 14312,
#    'start': 158.52,
#    'end': 159.36,
#    'text': '俺心の中では',
#    'tokens': [51134, 37334, 7945, 2972, 5975, 16719, 51176],
#    'temperature': 0.0,
#    'avg_logprob': -0.4857870526788359,
#    'compression_ratio': 1.7896253602305476,
#    'no_speech_prob': 0.06274664402008057},
#   {'id': 93,
#    'seek': 14312,
#    'start': 159.36,
#    'end': 161.36,
#    'text': 'いやお前なんて結局腐催だからなと思いながら',
#    'tokens': [51176,
#     18524,
#     6117,
#     8945,
#     11847,
#     2996,
#     17144,
#     34703,
#     21184,
#     238,
#     161,
#     9915,
#     33183,
#     3203,
#     22372,
#     1764,
#     3203,
#     5142,
#     5154,
#     51276],
#    'temperature': 0.0,
#    'avg_logprob': -0.4857870526788359,
#    'compression_ratio': 1.7896253602305476,
#    'no_speech_prob': 0.06274664402008057},
#   {'id': 94,
#    'seek': 14312,
#    'start': 161.36,
#    'end': 162.52,
#    'text': 'お腹の出るからで',
#    'tokens': [51276, 6117, 21184, 117, 2972, 7781, 4895, 11046, 2474, 51334],
#    'temperature': 0.0,
#    'avg_logprob': -0.4857870526788359,
#    'compression_ratio': 1.7896253602305476,
#    'no_speech_prob': 0.06274664402008057},
#   {'id': 95,
#    'seek': 14312,
#    'start': 162.52,
#    'end': 163.56,
#    'text': 'どうか言われよ',
#    'tokens': [51334, 18395, 3703, 12009, 9206, 4132, 5591, 51386],
#    'temperature': 0.0,
#    'avg_logprob': -0.4857870526788359,
#    'compression_ratio': 1.7896253602305476,
#    'no_speech_prob': 0.06274664402008057},
#   {'id': 96,
#    'seek': 14312,
#    'start': 163.56,
#    'end': 163.88,
#    'text': 'はい',
#    'tokens': [51386, 11050, 51402],
#    'temperature': 0.0,
#    'avg_logprob': -0.4857870526788359,
#    'compression_ratio': 1.7896253602305476,
#    'no_speech_prob': 0.06274664402008057},
#   {'id': 97,
#    'seek': 14312,
#    'start': 163.88,
#    'end': 165.08,
#    'text': 'ことあった俺不足が呼びてんだから',
#    'tokens': [51402,
#     13235,
#     3590,
#     10102,
#     37334,
#     1960,
#     37236,
#     5142,
#     38718,
#     38761,
#     2996,
#     26983,
#     11046,
#     51462],
#    'temperature': 0.0,
#    'avg_logprob': -0.4857870526788359,
#    'compression_ratio': 1.7896253602305476,
#    'no_speech_prob': 0.06274664402008057},
#   {'id': 98,
#    'seek': 14312,
#    'start': 165.08,
#    'end': 166.32,
#    'text': 'ことあって見るよって言って',
#    'tokens': [51462,
#     13235,
#     3590,
#     6102,
#     10470,
#     4895,
#     5591,
#     6102,
#     12009,
#     6102,
#     51524],
#    'temperature': 0.0,
#    'avg_logprob': -0.4857870526788359,
#    'compression_ratio': 1.7896253602305476,
#    'no_speech_prob': 0.06274664402008057},
#   {'id': 99,
#    'seek': 14312,
#    'start': 166.32,
#    'end': 167.24,
#    'text': 'はいことあったさよなら',
#    'tokens': [51524, 11050, 13235, 3590, 10102, 6722, 5591, 42540, 51570],
#    'temperature': 0.0,
#    'avg_logprob': -0.4857870526788359,
#    'compression_ratio': 1.7896253602305476,
#    'no_speech_prob': 0.06274664402008057},
#   {'id': 100,
#    'seek': 14312,
#    'start': 167.24,
#    'end': 168.56,
#    'text': 'すぐにしてくるんで',
#    'tokens': [51570, 2659, 35849, 4108, 8822, 6134, 4895, 35356, 51636],
#    'temperature': 0.0,
#    'avg_logprob': -0.4857870526788359,
#    'compression_ratio': 1.7896253602305476,
#    'no_speech_prob': 0.06274664402008057},
#   {'id': 101,
#    'seek': 14312,
#    'start': 168.56,
#    'end': 169.32,
#    'text': '不足をしてから',
#    'tokens': [51636, 1960, 37236, 5998, 8822, 11046, 51674],
#    'temperature': 0.0,
#    'avg_logprob': -0.4857870526788359,
#    'compression_ratio': 1.7896253602305476,
#    'no_speech_prob': 0.06274664402008057},
#   {'id': 102,
#    'seek': 14312,
#    'start': 169.32,
#    'end': 171.28,
#    'text': '本息で首を居けなくなった',
#    'tokens': [51674,
#     8802,
#     26460,
#     2474,
#     25444,
#     5998,
#     9636,
#     227,
#     7625,
#     40252,
#     3203,
#     10102,
#     51772],
#    'temperature': 0.0,
#    'avg_logprob': -0.4857870526788359,
#    'compression_ratio': 1.7896253602305476,
#    'no_speech_prob': 0.06274664402008057},
#   {'id': 103,
#    'seek': 14312,
#    'start': 171.28,
#    'end': 172.92000000000002,
#    'text': '結局お前は全然なんだ',
#    'tokens': [51772,
#     17144,
#     34703,
#     6117,
#     8945,
#     3065,
#     11319,
#     5823,
#     33383,
#     51854],
#    'temperature': 0.0,
#    'avg_logprob': -0.4857870526788359,
#    'compression_ratio': 1.7896253602305476,
#    'no_speech_prob': 0.06274664402008057},
#   {'id': 104,
#    'seek': 17292,
#    'start': 172.92,
#    'end': 173.92,
#    'text': 'そういうとりめちゃくん',
#    'tokens': [50364, 9955, 9444, 3193, 5095, 11429, 18930, 6134, 3225, 50414],
#    'temperature': 0.0,
#    'avg_logprob': -0.4011789270349451,
#    'compression_ratio': 1.736842105263158,
#    'no_speech_prob': 0.019793769344687462},
#   {'id': 105,
#    'seek': 17292,
#    'start': 173.92,
#    'end': 175.28,
#    'text': '死ぬほど不足って',
#    'tokens': [50414, 16989, 487, 105, 29050, 1960, 37236, 6102, 50482],
#    'temperature': 0.0,
#    'avg_logprob': -0.4011789270349451,
#    'compression_ratio': 1.736842105263158,
#    'no_speech_prob': 0.019793769344687462},
#   {'id': 106,
#    'seek': 17292,
#    'start': 175.28,
#    'end': 176.79999999999998,
#    'text': '死ぬほど不足って',
#    'tokens': [50482, 16989, 487, 105, 29050, 1960, 37236, 6102, 50558],
#    'temperature': 0.0,
#    'avg_logprob': -0.4011789270349451,
#    'compression_ratio': 1.736842105263158,
#    'no_speech_prob': 0.019793769344687462},
#   {'id': 107,
#    'seek': 17292,
#    'start': 176.79999999999998,
#    'end': 178.0,
#    'text': '死ぬほどないなから',
#    'tokens': [50558, 16989, 487, 105, 29050, 9311, 3203, 11046, 50618],
#    'temperature': 0.0,
#    'avg_logprob': -0.4011789270349451,
#    'compression_ratio': 1.736842105263158,
#    'no_speech_prob': 0.019793769344687462},
#   {'id': 108,
#    'seek': 17292,
#    'start': 178.0,
#    'end': 179.51999999999998,
#    'text': '抜いてもらう',
#    'tokens': [50618, 7235, 250, 18549, 4801, 5154, 2646, 50694],
#    'temperature': 0.0,
#    'avg_logprob': -0.4011789270349451,
#    'compression_ratio': 1.736842105263158,
#    'no_speech_prob': 0.019793769344687462},
#   {'id': 109,
#    'seek': 17292,
#    'start': 179.51999999999998,
#    'end': 180.48,
#    'text': '携帯で',
#    'tokens': [50694, 22220, 118, 4845, 107, 2474, 50742],
#    'temperature': 0.0,
#    'avg_logprob': -0.4011789270349451,
#    'compression_ratio': 1.736842105263158,
#    'no_speech_prob': 0.019793769344687462},
#   {'id': 110,
#    'seek': 17292,
#    'start': 180.48,
#    'end': 184.27999999999997,
#    'text': 'そういうと写真を見ながら抜いてもらうっていう',
#    'tokens': [50742,
#     9955,
#     9444,
#     3193,
#     5676,
#     247,
#     6303,
#     5998,
#     10470,
#     3203,
#     5142,
#     5154,
#     7235,
#     250,
#     18549,
#     4801,
#     5154,
#     2646,
#     46896,
#     50932],
#    'temperature': 0.0,
#    'avg_logprob': -0.4011789270349451,
#    'compression_ratio': 1.736842105263158,
#    'no_speech_prob': 0.019793769344687462},
#   {'id': 111,
#    'seek': 17292,
#    'start': 184.27999999999997,
#    'end': 185.88,
#    'text': '昔はやつは',
#    'tokens': [50932, 1431, 242, 3065, 7355, 9335, 3065, 51012],
#    'temperature': 0.0,
#    'avg_logprob': -0.4011789270349451,
#    'compression_ratio': 1.736842105263158,
#    'no_speech_prob': 0.019793769344687462},
#   {'id': 112,
#    'seek': 17292,
#    'start': 185.88,
#    'end': 186.92,
#    'text': 'ちょまり俺ケーター撮影が',
#    'tokens': [51012,
#     17411,
#     41446,
#     37334,
#     32639,
#     3384,
#     30736,
#     20559,
#     106,
#     16820,
#     5142,
#     51064],
#    'temperature': 0.0,
#    'avg_logprob': -0.4011789270349451,
#    'compression_ratio': 1.736842105263158,
#    'no_speech_prob': 0.019793769344687462},
#   {'id': 113,
#    'seek': 17292,
#    'start': 186.92,
#    'end': 188.67999999999998,
#    'text': '仕事でって嘘つきながら',
#    'tokens': [51064,
#     1550,
#     243,
#     6973,
#     2474,
#     6102,
#     10756,
#     246,
#     9335,
#     7016,
#     3203,
#     5142,
#     5154,
#     51152],
#    'temperature': 0.0,
#    'avg_logprob': -0.4011789270349451,
#    'compression_ratio': 1.736842105263158,
#    'no_speech_prob': 0.019793769344687462},
#   {'id': 114,
#    'seek': 17292,
#    'start': 188.67999999999998,
#    'end': 190.11999999999998,
#    'text': 'どうって',
#    'tokens': [51152, 18395, 6102, 51224],
#    'temperature': 0.0,
#    'avg_logprob': -0.4011789270349451,
#    'compression_ratio': 1.736842105263158,
#    'no_speech_prob': 0.019793769344687462}],
#  'language': 'ja'}
